# %% [markdown]
# # Lista de Estrutura Sequencial

# %% [markdown]
# #### 1. Faça um Programa que mostre a mensagem (print) "Alo mundo" na tela.

# %%
print("Alo mundo")
# Out:
# Alo mundo

# %% [markdown]
# #### 2. Faça um Programa que peça um número (input) e então mostre a mensagem: "O número informado foi [número]."

# %%
num = input("Insira um numero:")
print("O numero informado foi {}".format(num))
print(f"O numero informado foi {num}")
# Out:
# O numero informado foi 10
# O numero informado foi 10

# %% [markdown]
# #### 3. Faça um Programa que peça dois números e imprima a soma.

# %%
num1 = float(input("insira um numero para a soma:"))
num2 = float(input("insira outro numero para a soma:"))

print(f"A soma dos numeros é de: {num1 + num2}")
# Out:
# A soma dos numeros é de: 12.0

# %% [markdown]
# #### 4. Faça um Programa que peça as 4 notas bimestrais de um aluno e mostre a média de todas as notas.

# %%
nota1 = float(input("insira a primeira nota para a media:"))
nota2 = float(input("insira a segunda nota para a media:"))
nota3 = float(input("insira a terceira nota para a media:"))
nota4 = float(input("insira a quarta nota para a media:"))

soma = nota1 + nota2 + nota3 + nota4
media = soma / 4  

print(f"A media das notas é de: {media}")
# Out:
# A media das notas é de: 6.575

# %% [markdown]
# #### 5. Faça um Programa que converta metros para centímetros. Você pode pedir o comprimento em metros para o usuário (input).

# %%
metro = float(input("insira a metragem em metros para ser convertido em centimetros:"))

cm = metro * 100

print(f"Este comprimento em centímetros é {cm}")
# Out:
# Este comprimento em centímetros é 1000.0

# %% [markdown]
# #### 6. Faça um Programa que calcule a área de uma sala de um apartamento. Para isso, o seu programa precisa pedir a largura da sala, o comprimento da sala e imprimir a área em m² da sala.

# %%
largura = float(input("insira a largura:"))
comprimento = float(input("insira umo comprimento:"))

area = largura * comprimento

print(f"A area é de {area} m²")
# Out:
# A area é de 10.0 m²

# %% [markdown]
# #### 7. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês.

# %%
valor = float(input("insira uo valor ganho por hora:"))
horas = float(input("insira as horas trabalhadas no mes:"))

salario = valor * horas 

print(f"O salario do mes sera de {salario}")
# Out:
# O salario do mes sera de 6000.0

# %% [markdown]
# #### 8. Vamos criar um conversor de temperatura. Faça um Programa que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius.
# $C = \frac{5}{9}(F-32)$

# %%
f = float(input("insira a temperatura em Fahrenheit:"))

c = 5/9 * (f - 32)

print(f"A temperatura em Celsius sera de {c}")
# Out:
# A temperatura em Celsius sera de 26.11111111111111

# %% [markdown]
# #### 9. Faça um Programa que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
# $F = \frac{9}{5}C + 32$

# %%
c = float(input("insira a temperatura em Celsius:"))

f = 9/5 * c + 32

print(f"A temperatura em Fahrenheit sera de {f}")
# Out:
# A temperatura em Fahrenheit sera de 78.98

# %% [markdown]
# #### 10. Tendo como dados de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, usando a seguinte fórmula:
# $P = 72,7h - 58$
#
# Lembrando que "algoritmo" nada mais é do que um programa, como todos os outros que você vem fazendo

# %%
altura = float(input("insira sua altura:"))

p = 72.7 * altura - 58

print(f"Seu peso ideal seria de {p}")
# Out:
# Seu peso ideal seria de 75.041

# %% [markdown]
# #### 11. Tendo como dado de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, utilizando as seguintes fórmulas:
# ##### a. Para homens: $P = 72,7h - 58$
# ##### b. Para mulheres: $P = 62,1h - 44,7$

# %%
genero = input("insira o genero")

altura = float(input("insira sua altura:"))

if "homem" == genero: 

    ph = 72.7 * altura - 58
    print(f"Para homem o peso ideal seria de {ph}")

else:
    pm = 62.1 * altura - 44.7
    print(f"Para mulher o peso ideal seria de {pm}")
# Out:
# Para mulher o peso ideal seria de 68.943

# %% [markdown]
# #### 12. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês.

# %%
valor = float(input("insira uo valor ganho por hora:"))
horas = float(input("insira as horas trabalhadas no mes:"))

# %% [markdown]
# #####  Calcule o salário bruto (horas * salario por hora)

# %%
salario_bruto = valor * horas 

print(f"O salario bruto do mes sera de {salario_bruto}")
# Out:
# O salario bruto do mes sera de 30000.0

# %% [markdown]
# ##### Calcule o desconto do IR (11% do salário bruto)

# %%
ir = 0.11 * salario_bruto

print(f"O desconto do IR é de {ir}")
# Out:
# O desconto do IR é de 3300.0

# %% [markdown]
# ##### Calcule o desconto do INSS (8% do salário bruto)

# %%
inss = 0.08 * salario_bruto

print(f"O desconto do INSS é de {inss}")
# Out:
# O desconto do INSS é de 2400.0

# %% [markdown]
# ##### Calcule o desconto do sindicato (5% do salário bruto)

# %%
sind = 0.05 * salario_bruto

print(f"O desconto do Sindicato é de {sind}")
# Out:
# O desconto do Sindicato é de 1500.0

# %% [markdown]
# ##### Calcule o salário líquido (salário bruto - descontos)

# %%
salario_liquido = salario_bruto - (inss + ir + sind)

print(f"O salario depois dos descontos sera de {salario_liquido}")
# Out:
# O salario depois dos descontos sera de 22800.0

# %% [markdown]
# #### 13. Faça um programa para uma loja de tintas. O programa deverá pedir o tamanho em metros quadrados da área a ser pintada. Considere que a cobertura da tinta é de 1 litro para cada 3 metros quadrados e que a tinta é vendida em latas de 18 litros, que custam R\$ 80,00. Informe ao usuário a quantidades de latas de tinta a serem compradas e o preço total. (para simplificação nesse momento, não se preocupe em arredondar a quantidade de latas a serem compradas - vamos trabalhar isso em breve)

# %%
metragem = float(input("insira uo valor ganho por hora:"))

cobertura = metragem / 3 

latas = cobertura / 18 

preco = latas * 80

print(f'Serão necessárias {latas} latas, custando R$ {preco} no total')
# Out:
# Serão necessárias 1.1111111111111112 latas, custando R$ 88.88888888888889 no total

# %% [markdown]
# #### 14. Faça um programa que peça o tamanho de um arquivo para download (em MB) e a velocidade de um link de Internet (em Mbps), calcule e informe o tempo aproximado de download do arquivo usando este link (em minutos).
#
# Detalhe: MB significa megabyte, Mb (com b minúsculo) significa megabit. Um megabit é 1/8 de um megabyte.

# %%
tamanho = float(input("Qual sera o tamanho do arquivo para dowload e MB"))
velocidade = float(input("Qual sera a velocidade da internet em Mbps"))

megabits = tamanho * 8

tempo = megabits / velocidade

minutos = tempo / 60 

print(f'O tempo de download é de {minutos} minutos')
# Out:
# O tempo de download é de 3.8095238095238098 minutos
